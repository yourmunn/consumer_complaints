# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Code nef

# %%
df = pd.read_csv('complaints-2025-10-16_07_38.csv')
df.head()
# Out:
#   Date received                                            Product  \
# 0      04/12/25  Credit reporting or other personal consumer re...
# 1      09/30/25  Credit reporting or other personal consumer re...
# 2      10/03/25  Credit reporting or other personal consumer re...
# 3      03/26/24  Credit reporting or other personal consumer re...
# 4      01/26/23                        Checking or savings account
#
#         Sub-product                                              Issue  \
# 0  Credit reporting                        Improper use of your report
# 1  Credit reporting               Incorrect information on your report
# 2  Credit reporting               Incorrect information on your report
# 3  Credit reporting  Problem with a company's investigation into an...
# 4  Checking account                                Managing an account
#
#                                            Sub-issue  \
# 0      Reporting company used your report improperly
# ...
