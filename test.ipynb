# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### This part is to learn about the data
# Link: https://www.consumerfinance.gov/data-research/consumer-complaints/search/?dateRange=3y&date_received_max=2025-10-16&date_received_min=2022-10-16&page=1&searchField=all&size=25&sort=created_date_desc&tab=List

# %%
df = pd.read_csv('complaints-2025-10-16_07_38.csv')
df.head()

#check unique values of main columns -> from year 23 to year 24

min_date = min(df['Date received'])
max_date = max(df['Date received'])

df.head()
# Out:
#   Date received                                            Product  \
# 0      04/12/25  Credit reporting or other personal consumer re...
# 1      09/30/25  Credit reporting or other personal consumer re...
# 2      10/03/25  Credit reporting or other personal consumer re...
# 3      03/26/24  Credit reporting or other personal consumer re...
# 4      01/26/23                        Checking or savings account
#
#         Sub-product                                              Issue  \
# 0  Credit reporting                        Improper use of your report
# 1  Credit reporting               Incorrect information on your report
# 2  Credit reporting               Incorrect information on your report
# 3  Credit reporting  Problem with a company's investigation into an...
# 4  Checking account                                Managing an account
#
#                                            Sub-issue  \
# 0      Reporting company used your report improperly
# ...

# %%
#only ID complain number, others all text
df.columns.tolist()

product = df['Issue'].unique()
product

sub_product = df['Sub-issue'].unique()
sub_product
# Out:
# array(['Reporting company used your report improperly',
#        'Information belongs to someone else',
#        'Their investigation did not fix an error on your report',
#        'Funds not handled or disbursed as instructed',
#        'Account status incorrect',
#        "Credit card company isn't resolving a dispute about a purchase on your statement",
#        nan, "Credit inquiries on your report that you don't recognize",
#        'Investigation took more than 30 days',
#        'Problem with signing the paperwork',
#        'Was not notified of investigation status or results',
#        'Transaction was not authorized',
#        'Threatened or suggested your credit would be damaged',
#        'Card opened without my consent or knowledge', 'Debt is not yours',
#        'Account information incorrect', 'Personal information incorrect',
#        "Notification didn't disclose it was an attempt to collect a debt",
#        'Attempted to collect wrong amount',
# ...
